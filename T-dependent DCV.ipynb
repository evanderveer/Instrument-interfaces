# %% [markdown]
# # Temperature-dependent 4-wire resistivity

# %% [markdown]
# This notebook performs temperature-dependent DCV measurements on the Janis probe station. It is set up to use the Scientific Intruments Model 9700 temperature controller and HP 3458A 8.5 digit multimeter. The program sets a desired temperature on the controller, waits for it to stabilize, then collects a preset number of measurements of the DV voltage from the DMM with a preset time interval. It then moves on to the next temperature. The raw temperature-V data are saved to a text file.

# %% [markdown]
# ## Import libraries
# Imports the libraries required to run the program.

# %%
import pyvisa
import time
import os
import pandas as pd
import numpy as np
import plotly.graph_objects as go
import plotly.express as px

# %% [markdown]
# ## Functions
# This section contains function used in the rest of the program.

# %%
def connect_to_resources(GPIB_addr):
    """Connects to the multimeter and temperature controller using GPIB with the pyVISA library. 
        The input is a dictionary of instrument names and GPIB addresses as key,value pairs. 
        The output is a dictionary of instrument names and pyVISA resource objects as key,value pairs."""
    resman = pyvisa.ResourceManager()
    resources = {}
    for instr,addr in GPIB_addr.items():
        resources[instr] = resman.open_resource('GPIB0::' + str(addr) + '::INSTR')
        try:
            resources[instr].write('*IDN?')
            instr_ID = resources[instr].query('END 2;ID?')[:-2] #Remove carriage return and line feed characters from the end
            print('Connected at GPIB address ' + str(addr) + ' to instrument with ID: ' + instr_ID)
        except pyvisa.errors.VisaIOError:
            print('Error connecting to instrument at GPIB address ' + str(addr) + '. Please check the GPIB address and end-of-string character.\nProgram execution aborted.')
            raise pyvisa.errors.VisaIOError(-1073807265)
            break
    print('All instruments connected.\n')
    return(resources)

def configure_multimeter(instrument, perform_autocal):
    """Configures the digital multimeter for DCV measurements. 
        The input is a pyVISA resource object and a Boolean perform_autocal parameter which determines whether
        autocalibration is performed before further configuration. Autocal takes about 10 minutes.
        No output is generated.""" 
    instrument.clear()
    instrument.write('RESET; END 2')
    error_state = instrument.query('ERR?')
    
    if(error_state != '0\r\n'): #If errors are reported
        print('An error was reported by the instrument: ' + instrument.query('ERRSTR?'))
        raise pyvisa.errors.VisaIOError(0)
        
    instrument.write('DCV .03;APER 0.5;LOCK ON;DELAY 0')
    print('DC voltage measurement.\nIntegration window: 0.5 s.\nKeyboard lock on.') 
    
    print('Initializing...')
    time.sleep(10) #This can probably be done more elegantly using events, but it works for now.
    
    if(perform_autocal):
        instrument.write('INBUF ON')
        instrument.write('ACAL DCV')
        print('AUTOCAL running')
        for _ in range(22):
            print('.', end='')
            time.sleep(30)
        instrument.write('INBUF OFF')
        print('Autocalibration complete.')
    
    instrument.timeout = 10000 #To prevent timeout errors
    
    error_state = instrument.query('ERR?')
    if(error_state != '0\r\n'):
        print('An error was reported by the instrument: ' + instrument.query('ERRSTR?'))
        raise pyvisa.errors.VisaIOError(0)
    

def configure_tempcontr(instrument):
    """Configures the temperature controller.
    This function takes a pyVISA resource object as input and returns no output."""
    curr_temp = instrument.query('TA?')[3:-2]
    instrument.write('SET ' + curr_temp) 
    instrument.write('MHP 75.00')
    instrument.write('MODE 2')
    instrument.write('CTYP 1')
    print('\nCurrent temperature: ' + curr_temp + 'K.\nPID control on.\nMax. heater power 75%.')
    
def is_temp_stable(instrument, del_T, num_polls, poll_time_interval, setpoint):
    """This function determines whether the current temperature has stabilized at the setpoint. 
    It takes a pyVISA resource object, the required temperature accuracy, number of polls per setpoint, poll time interval
    and the current setpoint as imputs.
    The function returns True if the temperature is stable, False otherwise."""
    temps = [setpoint]
    for _ in range(3):
        temps.append(float(instrument.query('TA?')[3:-2]))
        time.sleep(poll_time_interval*num_polls*3/3)
    return(max(temps)-min(temps) < del_T)

def measure_temp_step(instrument_temp, instrument_mult, del_T, num_polls, poll_time_interval, setpoint):
    print('Temperature setpoint: ' + str(setpoint))
    instrument_temp.write('SET ' + str(setpoint))
    print('Waiting for temperature stabilization...')
    while not is_temp_stable(instrument_temp, del_T, num_polls, poll_time_interval, setpoint): 
        #Wait until the temperature has stabilized
        time.sleep(30)
    time_now = time.localtime()
    print(f'Temperature stable. Time: {time_now.tm_year}-{time_now.tm_mon}-{time_now.tm_mday} {time_now.tm_hour}:{time_now.tm_min}:{time_now.tm_sec}\n')
    
    temp_list = []
    dcv_list = []
    with open(filename, 'a') as f:
        for _ in range(num_polls):
            temp = float(instrument_temp.query('TA?')[3:-2])
            dcv = float(instrument_mult.read()[:-2])
            f.write(str(temp) + ',' + str(dcv) + '\n')
            temp_list.append(temp)
            dcv_list.append(dcv)
            time.sleep(poll_time_interval)
    return(temp_list, dcv_list)

def update_graph(fig, df):
    if(fig.data == ()):
        fig.add_trace(go.Scatter(x=df['Temp'], y=df['DCV'], mode='markers+lines', error_x=
                         dict(type='data',
                              array=df['Tempstd'],
                              visible=True),
                              error_y=
                         dict(type='data',
                              array=df['DCV_std'],
                              visible=True)
                                )
                     )
    else:
        with fig.batch_update():
            fig.data[0]['y'] = df['DCV']
            fig.data[0]['x'] = df['Temp']
            fig.data[0]['error_y'] = dict(type='data',
                                          array=df['DCV_std'],
                                          visible=True)
            fig.data[0]['error_x'] = dict(type='data',
                                          array=df['Tempstd'],
                                          visible=True)

# %% [markdown]
# ## Measurement parameters
# This section defines the instrument and program parameters used during the measurements.

# %%
output_folder = 'C:\\Users\\F110216\\Documents\\DATA\\EV112_reduced\\DCV\\'
if not os.path.exists(output_folder):
    os.mkdir(output_folder)
output_file_name = 'DCV_Cooling_Heating_210-10K_0.5uA'

#The temperature setpoints must be supplied as an iterator of setpoint values.
temp_setpts =  np.round(list(np.linspace(75,10,14))+list(np.linspace(10,210,41)),3)

#Set the time interval between measurements from the multimeter in seconds. 
#The interval should always be larger than the integration window (0.5 s)
#to prevent double measurements. 2 s is a good default value.
poll_time_interval = 2

#Number of measurements collected from the multimeter per temperature step.
num_polls = 10

#Required temperature accuracy. This value represents the maximum temperature 
#deviation (in K) allowed between three measurements in a time period equal 
#to poll_time_interval*num_polls.
del_T = 0.5

#Set true to perform autocalibration before starting the measurement. 
#Autocal should be run once every 24 hours or after a temperature change of
#more than 1 K. The procedure takes abour 10 minutes.
perform_autocal = False

#GPIB adresses of the temperature controller and multimeter.
GPIB_addr = {'temp':15, 'mult':22}

# %% [markdown]
# ## Instrument setup
# This section sets up the instruments for the measurements.

# %%
try:
    resources = connect_to_resources(GPIB_addr)
    configure_multimeter(resources['mult'], perform_autocal)
    configure_tempcontr(resources['temp'])
except Exception as e:
    print('\nInstrument setup failed.')
else:
    print('\nInstrument setup successful.')
# Out:
# Connected at GPIB address 15 to instrument with ID: Scientific Instruments,9700,0499,1.11
# Connected at GPIB address 22 to instrument with ID: HP3458A
# All instruments connected.
#
# DC voltage measurement.
# Integration window: 0.5 s.
# Keyboard lock on.
# Initializing...
#
# Current temperature: 74.601K.
# PID control on.
# Max. heater power 75%.
#
# Instrument setup successful.

# %% [markdown]
# ## Plot
# Create the real-time plot of the resistance.

# %%
df = pd.DataFrame(columns=['Temp', 'Tempstd', 'DCV', 'DCV_std'], index=temp_setpts) #For plotting
fig = go.FigureWidget()
fig.update_xaxes(title='Temperature (K)')
fig.update_yaxes(title='DC Voltage (V)')
fig
# Out:
# FigureWidget({
#     'data': [],
#     'layout': {'template': '...',
#                'xaxis': {'title': {'text': 'T…

# %% [markdown]
# ## Measurement loop
# This section contains the main measurement loop.

# %%
filename_counter = 0
filename = output_folder + output_file_name + '_' + str(filename_counter) + '.txt'
while os.path.isfile(filename):
    filename_counter += 1
    filename = output_folder + output_file_name + '_' + str(filename_counter) + '.txt'
else:
    print('Filename: ' + filename, end='\n')
    resources['mult'].write('LOCK ON')
    with open(filename, 'w') as f:
        f.write('Temperature(K),DC voltage(V)\n')
    
    
    for setpoint in temp_setpts:
        temp_list,dcv_list = measure_temp_step(resources['temp'], resources['mult'], del_T, num_polls, poll_time_interval, setpoint)
        df['Temp'][setpoint],df['DCV'][setpoint],df['Tempstd'][setpoint],df['DCV_std'][setpoint]=\
        np.mean(temp_list),np.mean(dcv_list),np.std(temp_list),np.std(dcv_list)
        update_graph(fig, df)
    
    
    print('\nMeasurement finished.')  
resources['mult'].write('LOCK OFF');
# Out:
# Filename: C:\Users\F110216\Documents\DATA\EV112_reduced\DCV\DCV_Cooling_Heating_210-10K_0.5uA_3.txt
# Temperature setpoint: 75.0
# Waiting for temperature stabilization...
# Temperature stable. Time: 2022-5-11 17:48:21
#
# Temperature setpoint: 70.0
# Waiting for temperature stabilization...
# Temperature stable. Time: 2022-5-11 17:55:42
#
# Temperature setpoint: 65.0
# Waiting for temperature stabilization...
# Temperature stable. Time: 2022-5-11 18:3:3
#
# Temperature setpoint: 60.0
# Waiting for temperature stabilization...
# Temperature stable. Time: 2022-5-11 18:8:54
#
# Temperature setpoint: 55.0
# Waiting for temperature stabilization...
# Temperature stable. Time: 2022-5-11 18:14:45
#
# Temperature setpoint: 50.0
# Waiting for temperature stabilization...
# Temperature stable. Time: 2022-5-11 18:19:6
#
# Temperature setpoint: 45.0
# Waiting for temperature stabilization...
# Temperature stable. Time: 2022-5-11 18:23:27
#
# Temperature setpoint: 40.0
# Waiting for temperature stabilization...
# Temperature stable. Time: 2022-5-11 18:27:48
#
# Temperature setpoint: 35.0
# Waiting for temperature stabilization...
# Temperature stable. Time: 2022-5-11 18:30:39
#
# Temperature setpoint: 30.0
# Waiting for temperature stabilization...
# Temperature stable. Time: 2022-5-11 18:33:29
#
# Temperature setpoint: 25.0
# Waiting for temperature stabilization...
# Temperature stable. Time: 2022-5-11 18:36:20
#
# Temperature setpoint: 20.0
# Waiting for temperature stabilization...
# Temperature stable. Time: 2022-5-11 18:39:11
#
# Temperature setpoint: 15.0
# Waiting for temperature stabilization...
# Temperature stable. Time: 2022-5-11 18:42:2
#
# Temperature setpoint: 10.0
# Waiting for temperature stabilization...
# Temperature stable. Time: 2022-5-11 18:44:52
#
# Temperature setpoint: 10.0
# Waiting for temperature stabilization...
# Temperature stable. Time: 2022-5-11 18:46:13
#
# Temperature setpoint: 15.0
# Waiting for temperature stabilization...
# Temperature stable. Time: 2022-5-11 18:49:4
#
# Temperature setpoint: 20.0
# Waiting for temperature stabilization...
# Temperature stable. Time: 2022-5-11 18:51:54
#
# Temperature setpoint: 25.0
# Waiting for temperature stabilization...
# Temperature stable. Time: 2022-5-11 18:54:45
#
# Temperature setpoint: 30.0
# Waiting for temperature stabilization...
# Temperature stable. Time: 2022-5-11 18:57:36
#
# Temperature setpoint: 35.0
# Waiting for temperature stabilization...
# Temperature stable. Time: 2022-5-11 19:0:27
#
# Temperature setpoint: 40.0
# Waiting for temperature stabilization...
# Temperature stable. Time: 2022-5-11 19:3:18
#
# Temperature setpoint: 45.0
# Waiting for temperature stabilization...
# Temperature stable. Time: 2022-5-11 19:7:39
#
# Temperature setpoint: 50.0
# Waiting for temperature stabilization...
# Temperature stable. Time: 2022-5-11 19:12:0
#
# Temperature setpoint: 55.0
# Waiting for temperature stabilization...
# Temperature stable. Time: 2022-5-11 19:16:20
#
# Temperature setpoint: 60.0
# Waiting for temperature stabilization...
# Temperature stable. Time: 2022-5-11 19:22:11
#
# Temperature setpoint: 65.0
# Waiting for temperature stabilization...
# Temperature stable. Time: 2022-5-11 19:28:2
#
# Temperature setpoint: 70.0
# Waiting for temperature stabilization...
# Temperature stable. Time: 2022-5-11 19:32:23
#
# Temperature setpoint: 75.0
# Waiting for temperature stabilization...
# Temperature stable. Time: 2022-5-11 19:36:44
#
# Temperature setpoint: 80.0
# Waiting for temperature stabilization...
# Temperature stable. Time: 2022-5-11 19:42:35
#
# Temperature setpoint: 85.0
# Waiting for temperature stabilization...
# Temperature stable. Time: 2022-5-11 19:48:26
#
# Temperature setpoint: 90.0
# Waiting for temperature stabilization...
# Temperature stable. Time: 2022-5-11 19:54:17
#
# Temperature setpoint: 95.0
# Waiting for temperature stabilization...
# Temperature stable. Time: 2022-5-11 20:0:8
#
# Temperature setpoint: 100.0
# Waiting for temperature stabilization...
# Temperature stable. Time: 2022-5-11 20:7:29
#
# Temperature setpoint: 105.0
# Waiting for temperature stabilization...
# Temperature stable. Time: 2022-5-11 20:14:50
#
# Temperature setpoint: 110.0
# Waiting for temperature stabilization...
# Temperature stable. Time: 2022-5-11 20:22:12
#
# Temperature setpoint: 115.0
# Waiting for temperature stabilization...
# Temperature stable. Time: 2022-5-11 20:31:3
#
# Temperature setpoint: 120.0
# Waiting for temperature stabilization...
# Temperature stable. Time: 2022-5-11 20:39:54
#
# Temperature setpoint: 125.0
# Waiting for temperature stabilization...
# Temperature stable. Time: 2022-5-11 20:48:45
#
# Temperature setpoint: 130.0
# Waiting for temperature stabilization...
# Temperature stable. Time: 2022-5-11 20:54:36
#
# Temperature setpoint: 135.0
# Waiting for temperature stabilization...
# Temperature stable. Time: 2022-5-11 21:0:27
#
# Temperature setpoint: 140.0
# Waiting for temperature stabilization...
# Temperature stable. Time: 2022-5-11 21:6:19
#
# Temperature setpoint: 145.0
# Waiting for temperature stabilization...
# Temperature stable. Time: 2022-5-11 21:13:40
#
# Temperature setpoint: 150.0
# Waiting for temperature stabilization...
# Temperature stable. Time: 2022-5-11 21:19:31
#
# Temperature setpoint: 155.0
# Waiting for temperature stabilization...
# Temperature stable. Time: 2022-5-11 21:26:52
#
# Temperature setpoint: 160.0
# Waiting for temperature stabilization...
# Temperature stable. Time: 2022-5-11 21:34:13
#
# Temperature setpoint: 165.0
# Waiting for temperature stabilization...
# Temperature stable. Time: 2022-5-11 21:41:34
#
# Temperature setpoint: 170.0
# Waiting for temperature stabilization...
# Temperature stable. Time: 2022-5-11 21:48:55
#
# Temperature setpoint: 175.0
# Waiting for temperature stabilization...
# Temperature stable. Time: 2022-5-11 21:56:16
#
# Temperature setpoint: 180.0
# Waiting for temperature stabilization...
# Temperature stable. Time: 2022-5-11 22:3:38
#
# Temperature setpoint: 185.0
# Waiting for temperature stabilization...
# Temperature stable. Time: 2022-5-11 22:9:29
#
# Temperature setpoint: 190.0
# Waiting for temperature stabilization...
# Temperature stable. Time: 2022-5-11 22:13:50
#
# Temperature setpoint: 195.0
# Waiting for temperature stabilization...
# Temperature stable. Time: 2022-5-11 22:21:11
#
# Temperature setpoint: 200.0
# Waiting for temperature stabilization...
# Temperature stable. Time: 2022-5-11 22:27:2
#
# Temperature setpoint: 205.0
# Waiting for temperature stabilization...
# Temperature stable. Time: 2022-5-11 22:32:53
#
# Temperature setpoint: 210.0
# Waiting for temperature stabilization...
# Temperature stable. Time: 2022-5-11 22:38:44
#
#
# Measurement finished.
